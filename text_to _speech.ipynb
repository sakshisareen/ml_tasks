# %%
# !pip3 install pyttsx3
# !pip3 install PyPDF2
# Out:
# Requirement already satisfied: pyttsx3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.90)
# Requirement already satisfied: pyobjc>=2.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-core==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AddressBook==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Automator==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CFNetwork==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Cocoa==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreAudio==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreData==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreServices==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreText==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-DiscRecording==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-LaunchServices==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-OSAKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Quartz==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Security==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SearchKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SyncServices==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-WebKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreLocation==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-IOSurface==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-NetFS==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AVFoundation==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreMedia==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-StoreKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SceneKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-libdispatch==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-libxpc==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Accounts==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-EventKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-GameCenter==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Social==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-GameKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AVKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-GameController==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MapKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SpriteKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CloudKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-FinderSync==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Contacts==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ContactsUI==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Metal==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MetalKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ModelIO==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Photos==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-PhotosUI==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-GameplayKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Intents==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SafariServices==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ColorSync==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreML==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Vision==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AdSupport==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-BusinessChat==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Network==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-UserNotifications==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CoreMotion==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-FileProvider==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-OSLog==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-PencilKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-PushKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Speech==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Accessibility==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AdServices==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CallKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ClassKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-KernelManagement==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MLCompute==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-PassKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ReplayKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ScreenTime==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Virtualization==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-DataDetection==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-IntentsUI==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MailKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MetricKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-PHASE==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ShazamKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-AVRouting==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-HealthKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-MetalFX==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SafetyKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Cinematic==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Symbols==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-CalendarStore==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-Collaboration==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-FSEvents==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-InstantMessage==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.0)
# Requirement already satisfied: PyPDF2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.0.1)

# %%
import PyPDF2 
import pyttsx3 
  
# path of the PDF file 
path = open('myfile.pdf', 'rb')

# %%
pdfReader = PyPDF2.PdfReader(path) 
  
# the page with which you want to start 
# this will read the page of 25th page. 
from_page = pdfReader.pages[1] 

# extracting the text from the PDF 
text = from_page.extract_text() 
  
# reading the text 
speak = pyttsx3.init() 
speak.say(text) 
speak.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyttsx3/__init__.py:20, in init(driverName, debug)
#      19 try:
# ---> 20     eng = _activeEngines[driverName]
#      21 except KeyError:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/weakref.py:136, in WeakValueDictionary.__getitem__(self, key)
#     135     self._commit_removals()
# --> 136 o = self.data[key]()
#     137 if o is None:
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# /Users/sakshi/Desktop/Applied_AI/ML2/text_to _speech.ipynb Cell 3 line 1
#       <a href='vscode-notebook-cell:/Users/sakshi/Desktop/Applied_AI/ML2/text_to%20_speech.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> text = from_page.extract_text()
#      <a href='vscode-notebook-cell:/Users/sakshi/Desktop/Applied_AI/ML2/text_to%20_speech.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> # reading the text
# ---> <a href='vscode-notebook-cell:/Users/sakshi/Desktop/Applied_AI/ML2/text_to%20_speech.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> speak = pyttsx3.init()
#      <a href='vscode-notebook-cell:/Users/sakshi/Desktop/Applied_AI/ML2/text_to%20_speech.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> speak.say(text)
#      <a href='vscode-notebook-cell:/Users/sakshi/Desktop/Applied_AI/ML2/text_to%20_speech.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> speak.runAndWait()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyttsx3/__init__.py:22, in init(driverName, debug)
#      20     eng = _activeEngines[driverName]
#      21 except KeyError:
# ---> 22     eng = Engine(driverName, debug)
#      23     _activeEngines[driverName] = eng
#      24 return eng
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyttsx3/engine.py:30, in Engine.__init__(self, driverName, debug)
#      20 def __init__(self, driverName=None, debug=False):
#      21     """
#      22     Constructs a new TTS engine instance.
#      23
#    (...)
#      28     @type debug: bool
#      29     """
# ---> 30     self.proxy = driver.DriverProxy(weakref.proxy(self), driverName, debug)
#      31     # initialize other vars
#      32     self._connects = {}
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyttsx3/driver.py:50, in DriverProxy.__init__(self, engine, driverName, debug)
#      48 # import driver module
#      49 name = 'pyttsx3.drivers.%s' % driverName
# ---> 50 self._module = importlib.import_module(name)
#      51 # build driver instance
#      52 self._driver = self._module.buildDriver(weakref.proxy(self))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyttsx3/drivers/nsss.py:12
#       8 def buildDriver(proxy):
#       9     return NSSpeechDriver.alloc().initWithProxy(proxy)
# ---> 12 class NSSpeechDriver(NSObject):
#      13     @objc.python_method
#      14     def initWithProxy(self, proxy):
#      15         self = super(NSSpeechDriver, self).init()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyttsx3/drivers/nsss.py:13, in NSSpeechDriver()
#      12 class NSSpeechDriver(NSObject):
# ---> 13     @objc.python_method
#      14     def initWithProxy(self, proxy):
#      15         self = super(NSSpeechDriver, self).init()
#      16         if self:
#
# NameError: name 'objc' is not defined
